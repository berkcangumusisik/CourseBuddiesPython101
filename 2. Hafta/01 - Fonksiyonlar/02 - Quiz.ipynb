# %% [markdown]
# # Soru 1
#
# Hangi Python anahtar sözcüğü bir fonksiyon tanımının başlangıcını gösterir?
#
# - continue
# - def
# - return
# - rad
#
# CEVAP : def

# %% [markdown]
# # SORU 2
# Python’da, fonksiyonu oluşturan kod bloğunun sonunu nasıl belirtirsiniz?
# - Fonksiyonu başlatmak için kullanılan eşleşen küme ayracı eklersiniz ” } “
# - İki nokta üst üste karakterini (:) bir satırın ilk sütununa koyarsınız
# - Def anahtar kelimesiyle aynı girinti düzeyine gelene kadar boşlukları silersiniz.
# - En az 10 tire içeren bir satır eklersiniz
#
# CEVAP: Def anahtar kelimesiyle aynı girinti düzeyine gelene kadar boşlukları silersiniz.

# %% [markdown]
# # SORU 3
# Python’da input () özelliği en iyi tanımlayan nedir?
# - Koşullu bir ifade
# - Merkezi işlem birimi
# - Yerleşik(hazır) bir fonksiyon
# - Kullanıcı tarafından tanımlanmış bir fonksiyon
#
# CEVAP: Yerleşik(hazır) bir fonksiyon

# %% [markdown]
# # SORU 4
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # SORU 5
# Aşağıdaki Python kodunda, aşağıdakilerden hangisi bir fonksiyonun “argüman”ı veya “girdi”si dir?
# x = ‘banana’
# y = max(x)
# z = y * 2
# - x
# - max
# - ‘banana’
# - y
#
# Cevap : x

# %% [markdown]
# # SORU 6
# ![image.png](attachment:image.png)
# CEVAP 10 20

# %% [markdown]
# # SORU 7
# Aşağıdaki Python programının hangi satırı asla çalışmayacak?
#
# def stuff():
#
#     print(‘Hello’)
#     return
#     print(‘World’)
#
# stuff()
# - print(‘Hello’)
# - print (‘World’)
# - return
# - stuff()
# - def stuff():
#
#
# CEVAP : print (‘World’)

# %% [markdown]
# # SORU 8
# ![image.png](attachment:image.png)

# %% [markdown]
# # SORU 9
# Aşağıdaki Python kodu ne yazdırır? (Bunun biraz kurnaz bir soru olduğunu ve kodun birçok kişinin kusur / hata olarak değerlendireceği şeyi içerdiğini unutmayın - bu yüzden dikkatlice okuyun :) ).
#
# def addtwo(a, b):
#
#     added = a + b
#     return a
#
# x = addtwo(2, 7)
# print(x)
#
#
#
# - 7
# - 2
# - 14
# - 9
#
# CEVAP: 2

# %% [markdown]
# # SORU 10
# Kendi fonksiyonlarınızı yazmanın en önemli yararı nedir?
# - 10 satırdan fazla sıralı kod bulundurmaktan kaçınabilmek
# - Bir program 10 satırdan fazla olduğunda bir fonksiyon kullanmanız gerektiği kuralına uyabilmek
# - Hiçbir işlevin 10’dan fazla ifadeye sahip olamayacağı kuralına uyabilmek
# - Aynı kod bloğunu programınızda birden çok kez yazmaktan kaçınabilmek
#
# CEVAP: Aynı kod bloğunu programınızda birden çok kez yazmaktan kaçınabilmek
